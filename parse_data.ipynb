# %%
import numpy as np
imu_file = open('imu_output.txt','r')
lines = imu_file.readlines()

imu_data = []
value = []
for line in lines:
    if ('image' in line):
        if value:
            imu_data.append(value)
            value = []
    else:
        value.extend([float(i) for i in line.split()[1:]])
print (imu_data)
# Out:
# [[1.90577, 5.32256, -8.42498, -0.157512, 0.176116, 0.701438, 2.02921, 5.25174, -8.59527, -0.151831, 0.212998, 0.67156, 2.27234, 5.51326, -8.70237, -0.15246, 0.230458, 0.648727, 2.19734, 5.59629, -8.89341, -0.103468, 0.203146, 0.61952, 2.17353, 5.57129, -8.95431, -0.0569523, 0.157562, 0.580846, 2.1148, 5.46012, -8.86938, -0.0596205, 0.0966772, 0.520165, 2.09638, 5.21841, -8.73712, -0.0363761, 0.0251258, 0.474718, 2.03937, 5.03789, -8.59039, -0.00977522, -0.019408, 0.445902, 2.14917, 4.95467, -8.5949, -0.00803725, -0.0656887, 0.431611, 2.08174, 4.8506, -8.41415, 0.0158769, -0.0829584, 0.428609], [2.11091, 4.79182, -8.22583, 0.0252554, -0.0748525, 0.424362, 2.14544, 4.92773, -8.21825, 0.019143, -0.0458155, 0.431436, 2.25861, 5.12609, -8.34631, 0.00221514, -0.0220618, 0.432971, 2.24273, 5.37002, -8.28418, 0.0144065, -0.00961887, 0.41097, 2.21173, 5.42237, -8.13411, 0.0384652, 0.00883029, 0.377305, 2.17707, 5.3615, -8.24202, 0.0455222, 0.0333138, 0.320876, 2.11523, 5.13572, -8.17167, 0.00
# ...

# %%
print (len(imu_data), len(imu_data[1]))
# Out:
# 3337 78

# %%
for i in range (10):
    print(len(imu_data[i]))
# Out:
# 60
# 78
# 78
# 72
# 72
# 78
# 72
# 78
# 72
# 78

# %%
print (np.array(imu_data))
# Out:
# [ list([1.90577, 5.32256, -8.42498, -0.157512, 0.176116, 0.701438, 2.02921, 5.25174, -8.59527, -0.151831, 0.212998, 0.67156, 2.27234, 5.51326, -8.70237, -0.15246, 0.230458, 0.648727, 2.19734, 5.59629, -8.89341, -0.103468, 0.203146, 0.61952, 2.17353, 5.57129, -8.95431, -0.0569523, 0.157562, 0.580846, 2.1148, 5.46012, -8.86938, -0.0596205, 0.0966772, 0.520165, 2.09638, 5.21841, -8.73712, -0.0363761, 0.0251258, 0.474718, 2.03937, 5.03789, -8.59039, -0.00977522, -0.019408, 0.445902, 2.14917, 4.95467, -8.5949, -0.00803725, -0.0656887, 0.431611, 2.08174, 4.8506, -8.41415, 0.0158769, -0.0829584, 0.428609])
# ...
