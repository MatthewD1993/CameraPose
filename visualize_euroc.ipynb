# %%
import numpy as numpy
import matplotlib.pyplot as plt 
import pandas as pd

from mpl_toolkits.mplot3d import Axes3D

GROUND_TRUTH_FILE = '/home/cdeng/EuRoC/mav0/state_groundtruth_estimate0/data.csv'
groud_truth = pd.read_csv(GROUND_TRUTH_FILE)

# %%
groud_truth.keys()
# Out:
# Index(['#timestamp', ' p_RS_R_x [m]', ' p_RS_R_y [m]', ' p_RS_R_z [m]',
#        ' q_RS_w []', ' q_RS_x []', ' q_RS_y []', ' q_RS_z []',
#        ' v_RS_R_x [m s^-1]', ' v_RS_R_y [m s^-1]', ' v_RS_R_z [m s^-1]',
#        ' b_w_RS_S_x [rad s^-1]', ' b_w_RS_S_y [rad s^-1]',
#        ' b_w_RS_S_z [rad s^-1]', ' b_a_RS_S_x [m s^-2]',
#        ' b_a_RS_S_y [m s^-2]', ' b_a_RS_S_z [m s^-2]'],
#       dtype='object')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(*[groud_truth.ix[:,d].values for d in range(1,4)])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(groud_truth.ix[:,1].values, groud_truth.ix[:,2].values, groud_truth.ix[:,3].values)
plt.show()

# %%
print (type(groud_truth.ix[:,1].values))
# Out:
# <class 'numpy.ndarray'>
